# %% [markdown]
# ### Day 9: Reverse a Doubly Linked List
#
# - How to reverse a doubly linked list by swapping next and prev pointers.
# - How to update the head and tail correctly.
# - Understand how reversal differs from singly linked lists.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = self.tail = None

    def display(self):
        current = self.head
        while current:
            print(f'{current.data}', end=" -> ")
            current = current.next
        print("None")


    def insert_at_end(self, value):
        new_node = Node(value)

        if self.head is None:
            self.head = self.tail = new_node
            return    

        self.tail.next = new_node
        new_node.prev = self.tail
        self.tail = new_node

    def reverse_v1(self):
        current = self.head

        while current:
            # Swap next and prev
            current.next, current.prev = current.prev, current.next

            # Move to the next node (which is now the previous one)
            current = current.prev
         # Swap head and tail
        self.head, self.tail = self.tail, self.head


    def reverse_v2(self):
        prev = None
        current = self.head

        while current:
            next_node = current.next
            # Swap next and prev
            current.next = prev
            current.prev = next_node

            prev = current
            current = next_node

        # Update head and tail
        self.tail = self.head
        self.head = prev


a = DoublyLinkedList()
a.insert_at_end(2)
a.insert_at_end(3)
a.insert_at_end(4)
a.display()
a.reverse_v1()
a.display()
# Out:
# 2 -> 3 -> 4 -> None
# 4 -> 3 -> 2 -> None
